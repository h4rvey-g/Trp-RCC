# %%
import os
import celltypist
import scanpy
import subprocess
import polars as pl

# 获取 Git 仓库的根目录
git_root = subprocess.check_output(["git", "rev-parse", "--show-toplevel"]).strip().decode('utf-8')

# 更改当前工作目录到 Git 仓库的根目录
os.chdir(git_root)

# %%
# Read the reference data
adata_reference = scanpy.read("data/201.load_sc/reference.h5ad")

scanpy.pp.normalize_total(adata_reference, target_sum=1e4)
scanpy.pp.log1p(adata_reference)
adata_reference = adata_reference[adata_reference.obs['broad_type'] == 'T-cell']
# read data/205.sub_cluster/T_markers_ct.tsv
T_cells = pl.read_csv("data/205.sub_cluster/T_markers_ct.tsv", separator='\t')
# to np
T_cells = T_cells.to_numpy()
# filter adata reference.obs['annotation'] in T_cells
adata_reference = adata_reference[adata_reference.obs['annotation'].isin(T_cells[:, 0])]
# Train the celltypist model
T_model = celltypist.train(adata_reference, labels='annotation', n_jobs=40, feature_selection=True)

# Create the directory if it doesn't exist
os.makedirs("data/205.sub_cluster", exist_ok=True)

# Save the trained model
T_model.write("data/205.sub_cluster/T_model.pkl")
# Out:
# 🍳 Preparing data before training
# ✂️ 424 non-expressed genes are filtered out
# 🔬 Input data has 126632 cells and 19312 genes
# ⚖️ Scaling input data
# 🏋️ Training data using SGD logistic regression
# ⚠️ Warning: it may take a long time to train this dataset with 126632 cells and 19312 genes, try to downsample cells and/or restrict genes to a subset (e.g., hvgs)
# 🔎 Selecting features
# 🧬 2082 features are selected
# 🏋️ Starting the second round of training
# 🏋️ Training data using logistic regression
# ✅ Model training done!

# %%
adata_sc = scanpy.read("data/201.load_sc/sc_pre.h5ad")
T_cell_names = pl.read_csv("data/204.cluster/T_cell_names.tsv", separator="\t")
T_cell_names = T_cell_names.to_numpy()
# filter cells in T_cell_names
adata_sc = adata_sc[adata_sc.obs.index.isin(T_cell_names[:, 0])]
predictions_list = []

for dataset in adata_sc.obs["dataset"].unique():
    adata_subset = adata_sc[adata_sc.obs["dataset"] == dataset, :]
    scanpy.pp.normalize_total(adata_subset, target_sum=1e4)
    scanpy.pp.log1p(adata_subset)
    predictions = celltypist.annotate(
        adata_subset, model="data/205.sub_cluster/T_model.pkl", majority_voting=True
    )
    predictions_list.append(predictions.predicted_labels)
# Out:
# 🔬 Input data has 22167 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 15
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 5749 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 785 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 13368 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 13215 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 11485 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 14126 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 7078 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 2745 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 7854 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 943 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 23 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚠️ Warning: the input number of cells (23) is too few to conduct proper over-clustering; no majority voting is performed
# 🔬 Input data has 250 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 59 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 74 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 1528 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 2540 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 1328 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 73 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 4 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚠️ Warning: the input number of cells (4) is too few to conduct proper over-clustering; no majority voting is performed
# 🔬 Input data has 104 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 12 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚠️ Warning: the input number of cells (12) is too few to conduct proper over-clustering; no majority voting is performed
# 🔬 Input data has 9 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚠️ Warning: the input number of cells (9) is too few to conduct proper over-clustering; no majority voting is performed
# 🔬 Input data has 11 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚠️ Warning: the input number of cells (11) is too few to conduct proper over-clustering; no majority voting is performed
# 🔬 Input data has 180 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 723 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 11 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚠️ Warning: the input number of cells (11) is too few to conduct proper over-clustering; no majority voting is performed
# 🔬 Input data has 24 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚠️ Warning: the input number of cells (24) is too few to conduct proper over-clustering; no majority voting is performed
# 🔬 Input data has 90 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 25 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚠️ Warning: the input number of cells (25) is too few to conduct proper over-clustering; no majority voting is performed
# 🔬 Input data has 5677 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 1814 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 8250 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 2018 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 2726 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 1982 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 2868 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 333 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 3823 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 1485 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 1718 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 1300 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 1090 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 3735 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 196 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 542 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 864 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 1358 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 2640 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 1920 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 1127 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 4027 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 2030 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 1808 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 2586 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 2200 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 801 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 5081 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 3284 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 2055 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 5872 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 1512 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 418 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 2 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚠️ Warning: the input number of cells (2) is too few to conduct proper over-clustering; no majority voting is performed
# 🔬 Input data has 2 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚠️ Warning: the input number of cells (2) is too few to conduct proper over-clustering; no majority voting is performed
# 🔬 Input data has 16 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚠️ Warning: the input number of cells (16) is too few to conduct proper over-clustering; no majority voting is performed
# 🔬 Input data has 12 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚠️ Warning: the input number of cells (12) is too few to conduct proper over-clustering; no majority voting is performed
# 🔬 Input data has 27 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚠️ Warning: the input number of cells (27) is too few to conduct proper over-clustering; no majority voting is performed
# 🔬 Input data has 6 cells and 44806 genes
# 🔗 Matching reference genes in the model
# 🧬 2082 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚠️ Warning: the input number of cells (6) is too few to conduct proper over-clustering; no majority voting is performed
# sys:1: CategoricalRemappingWarning: Local categoricals have different encodings, expensive re-encoding is done to perform this merge operation. Consider using a StringCache or an Enum type if the categories are known in advance
# ---------------------------------------------------------------------------
# ShapeError                                Traceback (most recent call last)
# Cell In[3], line 18
#      15     predictions_list.append(predictions.predicted_labels)
#      17 # Combine all predictions into a single dataframe
# ---> 18 all_predictions = pl.concat([pl.DataFrame(pred) for pred in predictions_list])
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/site-packages/polars/functions/eager.py:185, in concat(items, how, rechunk, parallel)
#     183 if isinstance(first, pl.DataFrame):
#     184     if how == "vertical":
# --> 185         out = wrap_df(plr.concat_df(elems))
#     186     elif how == "vertical_relaxed":
#     187         out = wrap_ldf(
#     188             plr.concat_lf(
#     189                 [df.lazy() for df in elems],
#    (...)
#     193             )
#     194         ).collect(no_optimization=True)
#
# ShapeError: unable to append to a DataFrame of width 3 with a DataFrame of width 1

# %%
# drop elements with only one column in predictions_list
predictions_list = [pred for pred in predictions_list if pred.shape[1] > 1]
# concat
all_predictions = pl.concat([pl.from_pandas(pred, include_index=True) for pred in predictions_list])

# %%
# name first column as cell_name
all_predictions = all_predictions.rename({"None": "cell_name"})
all_predictions.write_csv("data/205.sub_cluster/predicted_labels_T.csv")
